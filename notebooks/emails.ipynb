# %%
import os
import pandas as pd

# Data Location within CC DS
data_location = os.path.join("..","data","external")
data_out_location = os.path.join("..","data","processed")

emails = pd.read_csv(os.path.join(data_location, "emails.csv"))

# %%
emails.head()
# Out:
#                                  Subject  \
# 0  RE: Pfeiffer Trail in Big Sur is Open
# 1           RE: Professional Development
# 2  RE: Pfeiffer Trail in Big Sur is Open
# 3          Orange Blossom Pot Luck Lunch
# 4                        Summer Pot Luck
#
#                                                 Body      From: (Name)  \
# 0  Sure � we�ll slide it in there.\r\n\r\n \r\n\r...    Andrea Huisden
# 1  I usually find benefit in these things � altho...       Rob O'Keefe
# 2  We can do a topline for you of those numbers. ...    Andrea Huisden
# 3                                               \r\n  Jennifer Johnson
# 4  Dear MCCVB Team,\r\n\r\n \r\n\r\nIn honor of N...  Jennifer Johnson
#
#                                      From: (Address) From: (Type)  \
# 0                          ahuisden@smarinsights.com         SMTP
# 1  /O=MCCVB/OU=EXCHANGE ADMINISTRATIVE GROUP (FYD...           EX
# 2                          ahuisden@smarinsights.com         SMTP
# ...
